# %%
#Variables for Numbers 
#How To Print Multiple Answers in Cells 
#Variables as Placeholders for Numbers 
#Names of the Variables Can be Reassinged

x = 7
x

# %%
x-2

# %%
x=10
x=x-2*5
x

# %%
#Prints Only the Final Line Of Code Unless Specified
#Overloading
x=10
y=20
z=31
print(x+y*z)
print(x-y*z)

# %%
mike = 10 
spike = 34 
mike + spike

# %%
#Excercises
#1.
x = 7
y = -2
z = 5
print((3*x)*(4+y) == 42)
#2.
print(-y-((x+3)/z) == 0)
# Out:
# True
# True
