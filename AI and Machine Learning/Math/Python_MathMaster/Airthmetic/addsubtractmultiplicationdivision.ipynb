# %%
#Addition
4+4
# Out:
# 8

# %%
#Subtraction
10-5
# Out:
# 5

# %%
#Multiplication 
3*3
# Out:
# 9

# %%
#Division 
8/2
# Out:
# 4.0

# %%
#Excercises 
#1.
5-(2/4)*(3/5)
# Out:
# 4.7

# %%
#2.
(4-5)/(3+5*6)
#Visualize the Math in Python Through Brackets.
# Out:
# -0.030303030303030304
