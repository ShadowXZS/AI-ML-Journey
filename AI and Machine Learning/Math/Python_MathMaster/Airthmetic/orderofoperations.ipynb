# %%
#Order of Operations 
#Please Excuse My Dear Aunt Sally
#PEMDAS

# %%
print((4 +3 ) * ( 2 - 1))
#Python Does not care about Spaces
# Out:
# 7

# %%
#Excercise 
#1.
print((4*5) / (7+3)) # Answer Should be Equal to 2 
#2. 
print(9/ (3+6) -1)# Answer Should be Equal to 0
# Out:
# 2.0
# 0.0

# %%
#Solution 
#Solved Correctly
