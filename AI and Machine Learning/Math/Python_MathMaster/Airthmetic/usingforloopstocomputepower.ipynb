# %%
#Using For Loops to Computer for Power
#Concept of For Loop 
#for x in [0,1,2,3]: = Where for and in are reserved keywords 
#    code
# When the Condition After In is met or Items after In is Exhausted it will exit the loop.
# range(0,3) Generates the Number from 1st Number to 1 - 2nd Number. 
# for x in range(0,3):
#    code

# %%
for i in [0,1,2,3]:
    print(i*2) # Variable used in For Loop Can be Used Inside For Loop: If same variable used in another for loop the value of the variable will be reassigned.

# %%
list(range(0,3))# List Function Can be Used to List the Range

# %%
for qwerty in range(0,3):
    print("This is the %gTh Iteration." %qwerty)# %g is Interpreted as a Single Chracter. 

for t in range(0,5):
    num = t**2
    print(num)

# %%
#Excercise
base = 2
for i in range(0,10):
    num = base**i
    print('%g to the power of %g is %g' %(base,i,num))

# %%
#Solution 
# He adds Base Variable. Updated the Excercise to Reflect the Same. 
# Scientific Notation Numbers.
