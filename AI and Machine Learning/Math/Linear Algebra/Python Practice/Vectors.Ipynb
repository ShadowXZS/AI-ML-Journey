# %%
import numpy as np
import matplotlib.pyplot as plt

v = np.array([2,5])
plt.figure()
plt.quiver(0,0, v[0], v[1], angles='xy', scale_units='xy', scale=1, color='r')
plt.xlim(-1,5)
plt.ylim(-1,6)
plt.grid()
plt.title("Reclaiming the Flow")
plt.show()
