# %%
import numpy as np
import matplotlib.pyplot as plt 
from PIL import Image

# %%
#Import Picture
pic = Image.open('Supporting Files\Mira.jpg')

#Lets have a look 
plt.imshow(pic)
plt.imshow(pic,cmap='gray')
plt.show()

#We need to convert it to floating-point precision
pic = np.array(pic)
plt.imshow(pic,cmap='gray')
plt.show()
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\M'
# <>:2: SyntaxWarning: invalid escape sequence '\M'
# C:\Users\goura\AppData\Local\Temp\ipykernel_6324\3217787682.py:2: SyntaxWarning: invalid escape sequence '\M'
#   pic = Image.open('Supporting Files\Mira.jpg')

# %%
#Singular Value Decomposition
U,S,V = np.linalg.svd(pic)

#plot the spectrum 
plt.plot(S,'s-')
plt.xlim([0,100])
plt.xlabel('Component Number')
plt.ylabel('Singular Value (\sigma)')
plt.show()
# Out:
# <>:8: SyntaxWarning: invalid escape sequence '\s'
# <>:8: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\goura\AppData\Local\Temp\ipykernel_6324\2667264589.py:8: SyntaxWarning: invalid escape sequence '\s'
#   plt.ylabel('Singular Value (\sigma)')

# %%
# Reconstruct the image based on some components 
# List the components you want to use for the reconstruction 
comps = np.arange(20,500)

# Recontruct the Low-Rank Version of the Picture 
reconPic = U[:,comps]@np.diag(S[comps]) @V[comps,:]

#Show the Original and reconstructed Pictures for Comparison 
plt.figure(figsize=(5,10))
plt.subplot(1,2,1)
plt.imshow(pic,cmap='gray')
plt.title('Components %s-%s' %(comps[0], comps[-1]))
plt.axis('off')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 6
#       3 comps = np.arange(0,5)
#       5 # Recontruct the Low-Rank Version of the Picture
# ----> 6 reconPic = U[:,comps]@np.diag(S[comps]) @V[comps,:]
#       8 #Show the Original and reconstructed Pictures for Comparison
#       9 plt.figure(figsize=(5,10))
#
# ValueError: matmul: Input operand 1 has a mismatch in its core dimension 0, with gufunc signature (n?,k),(k,m?)->(n?,m?) (size 3 is different from 1440)
